# %%
# !pip install lightgbm
# !pip install yellowbrick
# !pip install imblearn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, label_binarize
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_auc_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import SMOTE
import seaborn as sns
import warnings
from IPython.display import display

# Uyarıları kapat
warnings.filterwarnings('ignore')

# Sinyal gücü dönüştürme fonksiyonu
def convert_to_integer(value):
    if pd.isna(value) or value == '':
        return None
    elif isinstance(value, (int, float)):
        return value
    else:
        signal_strengths = [int(v) for v in value.split('-') if v]
        if signal_strengths:
            average_strength = round(sum(signal_strengths) / len(signal_strengths))
            return -average_strength
        else:
            return None

# Özellik listesi
features = ['frame.interface_id', 'frame.dlt', 'frame.offset_shift', 'frame.time_epoch', 'frame.time_delta',
            'frame.time_delta_displayed', 'frame.time_relative', 'frame.len', 'frame.cap_len', 'frame.marked',
            'frame.ignored', 'radiotap.version', 'radiotap.pad', 'radiotap.length', 'radiotap.present.tsft',
            'radiotap.present.flags', 'radiotap.present.rate', 'radiotap.present.channel', 'radiotap.present.fhss',
            'radiotap.present.dbm_antsignal', 'radiotap.present.dbm_antnoise', 'radiotap.present.lock_quality',
            'radiotap.present.tx_attenuation', 'radiotap.present.db_tx_attenuation', 'radiotap.present.dbm_tx_power',
            'radiotap.present.antenna', 'radiotap.present.db_antsignal', 'radiotap.present.db_antnoise',
            'radiotap.present.rxflags', 'radiotap.present.xchannel', 'radiotap.present.mcs', 'radiotap.present.ampdu',
            'radiotap.present.vht', 'radiotap.present.reserved', 'radiotap.present.rtap_ns', 'radiotap.present.vendor_ns',
            'radiotap.present.ext', 'radiotap.mactime', 'radiotap.flags.cfp', 'radiotap.flags.preamble',
            'radiotap.flags.wep', 'radiotap.flags.frag', 'radiotap.flags.fcs', 'radiotap.flags.datapad',
            'radiotap.flags.badfcs', 'radiotap.flags.shortgi', 'radiotap.datarate', 'radiotap.channel.freq',
            'radiotap.channel.type.turbo', 'radiotap.channel.type.cck', 'radiotap.channel.type.ofdm',
            'radiotap.channel.type.2ghz', 'radiotap.channel.type.5ghz', 'radiotap.channel.type.passive',
            'radiotap.channel.type.dynamic', 'radiotap.channel.type.gfsk', 'radiotap.channel.type.gsm',
            'radiotap.channel.type.sturbo', 'radiotap.channel.type.half', 'radiotap.channel.type.quarter',
            'radiotap.dbm_antsignal', 'radiotap.antenna', 'radiotap.rxflags.badplcp', 'wlan.fc.type_subtype',
            'wlan.fc.version', 'wlan.fc.type', 'wlan.fc.subtype', 'wlan.fc.ds', 'wlan.fc.frag', 'wlan.fc.retry',
            'wlan.fc.pwrmgt', 'wlan.fc.moredata', 'wlan.fc.protected', 'wlan.fc.order', 'wlan.duration', 'wlan.ra',
            'wlan.da', 'wlan.ta', 'wlan.sa', 'wlan.bssid', 'wlan.frag', 'wlan.seq', 'wlan.bar.type',
            'wlan.ba.control.ackpolicy', 'wlan.ba.control.multitid', 'wlan.ba.control.cbitmap',
            'wlan.bar.compressed.tidinfo', 'wlan.ba.bm', 'wlan.fcs_good', 'wlan_mgt.fixed.capabilities.ess',
            'wlan_mgt.fixed.capabilities.ibss', 'wlan_mgt.fixed.capabilities.cfpoll.ap',
            'wlan_mgt.fixed.capabilities.privacy', 'wlan_mgt.fixed.capabilities.preamble',
            'wlan_mgt.fixed.capabilities.pbcc', 'wlan_mgt.fixed.capabilities.agility',
            'wlan_mgt.fixed.capabilities.spec_man', 'wlan_mgt.fixed.capabilities.short_slot_time',
            'wlan_mgt.fixed.capabilities.apsd', 'wlan_mgt.fixed.capabilities.radio_measurement',
            'wlan_mgt.fixed.capabilities.dsss_ofdm', 'wlan_mgt.fixed.capabilities.del_blk_ack',
            'wlan_mgt.fixed.capabilities.imm_blk_ack', 'wlan_mgt.fixed.listen_ival', 'wlan_mgt.fixed.current_ap',
            'wlan_mgt.fixed.status_code', 'wlan_mgt.fixed.timestamp', 'wlan_mgt.fixed.beacon', 'wlan_mgt.fixed.aid',
            'wlan_mgt.fixed.reason_code', 'wlan_mgt.fixed.auth.alg', 'wlan_mgt.fixed.auth_seq',
            'wlan_mgt.fixed.category_code', 'wlan_mgt.fixed.htact', 'wlan_mgt.fixed.chanwidth',
            'wlan_mgt.fixed.fragment', 'wlan_mgt.fixed.sequence', 'wlan_mgt.tagged.all', 'wlan_mgt.ssid',
            'wlan_mgt.ds.current_channel', 'wlan_mgt.tim.dtim_count', 'wlan_mgt.tim.dtim_period',
            'wlan_mgt.tim.bmapctl.multicast', 'wlan_mgt.tim.bmapctl.offset', 'wlan_mgt.country_info.environment',
            'wlan_mgt.rsn.version', 'wlan_mgt.rsn.gcs.type', 'wlan_mgt.rsn.pcs.count', 'wlan_mgt.rsn.akms.count',
            'wlan_mgt.rsn.akms.type', 'wlan_mgt.rsn.capabilities.preauth', 'wlan_mgt.rsn.capabilities.no_pairwise',
            'wlan_mgt.rsn.capabilities.ptksa_replay_counter', 'wlan_mgt.rsn.capabilities.gtksa_replay_counter',
            'wlan_mgt.rsn.capabilities.mfpr', 'wlan_mgt.rsn.capabilities.mfpc', 'wlan_mgt.rsn.capabilities.peerkey',
            'wlan_mgt.tcprep.trsmt_pow', 'wlan_mgt.tcprep.link_mrg', 'wlan.wep.iv', 'wlan.wep.key', 'wlan.wep.icv',
            'wlan.tkip.extiv', 'wlan.ccmp.extiv', 'wlan.qos.tid', 'wlan.qos.priority', 'wlan.qos.eosp',
            'wlan.qos.ack', 'wlan.qos.amsdupresent', 'wlan.qos.buf_state_indicated1', 'wlan.qos.bit4',
            'wlan.qos.txop_dur_req', 'wlan.qos.buf_state_indicated2', 'data.len', 'class']

selected_features = ['frame.len', 'radiotap.length', 'radiotap.dbm_antsignal', 'radiotap.channel.freq', 'wlan.duration',
                    'radiotap.present.tsft', 'radiotap.channel.type.cck', 'radiotap.channel.type.ofdm', 'wlan.fc.type',
                    'wlan.fc.subtype', 'wlan.fc.ds', 'wlan.fc.frag', 'wlan.fc.retry', 'wlan.fc.pwrmgt', 'wlan.fc.moredata',
                    'wlan.fc.protected']

# Veri setlerini oku
awid2trn_data = pd.read_csv("/content/drive/MyDrive/AWID/AWID2/DATASET/AWID-CLS-R-Trn/AWID-CLS-R-Trn/1",
                            header=None, names=features, low_memory=False)
awid2trn_data = awid2trn_data.loc[:, selected_features + ['class']]

awid2tst_data = pd.read_csv("/content/drive/MyDrive/AWID/AWID2/DATASET/AWID-CLS-R-Tst/AWID-CLS-R-Tst/1",
                            header=None, names=features, low_memory=False)
awid2tst_data = awid2tst_data.loc[:, selected_features + ['class']]

# NaN ve '?' değerlerini temizle
awid2trn_data = awid2trn_data.replace(r'^\s*$', pd.NA, regex=True).replace('?', pd.NA).dropna()
awid2tst_data = awid2tst_data.replace(r'^\s*$', pd.NA, regex=True).replace('?', pd.NA).dropna()

# Injection sınıfını kaldır
awid2trn_data = awid2trn_data[awid2trn_data['class'] != 'injection']
awid2tst_data = awid2tst_data[awid2tst_data['class'] != 'injection']

# Özellik ve hedef değişkenleri ayır
X_awid2trn = awid2trn_data.loc[:, selected_features]
y_awid2trn = awid2trn_data['class']
X_awid2tst = awid2tst_data.loc[:, selected_features]
y_awid2tst = awid2tst_data['class']

# radiotap.dbm_antsignal dönüşümü
X_awid2trn['radiotap.dbm_antsignal'] = X_awid2trn['radiotap.dbm_antsignal'].apply(convert_to_integer)
X_awid2tst['radiotap.dbm_antsignal'] = X_awid2tst['radiotap.dbm_antsignal'].apply(convert_to_integer)

# Eksik değerleri doldur
X_awid2trn = X_awid2trn.fillna(X_awid2trn.mean(numeric_only=True))
X_awid2tst = X_awid2tst.fillna(X_awid2tst.mean(numeric_only=True))

# Min-max ölçeklendirme
columns_to_scale = ['frame.len', 'radiotap.length', 'radiotap.dbm_antsignal', 'wlan.duration']
columns_to_one_hot_encode = [col for col in X_awid2trn.columns if col not in columns_to_scale]

scaler = MinMaxScaler()
X_awid2trn[columns_to_scale] = scaler.fit_transform(X_awid2trn[columns_to_scale])
X_awid2tst[columns_to_scale] = scaler.transform(X_awid2tst[columns_to_scale])

# One-hot encoding
combined_data = pd.concat([X_awid2trn, X_awid2tst], axis=0)
combined_data = pd.get_dummies(combined_data, columns=columns_to_one_hot_encode)
X_awid2trn_encoded = combined_data[:len(X_awid2trn)]
X_awid2tst_encoded = combined_data[len(X_awid2trn):]

# SMOTE ile veri dengeleme
print("SMOTE öncesi sınıf dağılımı:")
print(y_awid2trn.value_counts())

smote = SMOTE(random_state=42)
X_awid2trn_encoded, y_awid2trn = smote.fit_resample(X_awid2trn_encoded, y_awid2trn)

print("SMOTE sonrası sınıf dağılımı:")
print(y_awid2trn.value_counts())

# K-Fold ayarları
stratified_kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Modeller
models = {
    "Decision Tree": DecisionTreeClassifier(max_depth=20, ccp_alpha=0.001, max_leaf_nodes=100, min_samples_leaf=2, random_state=42),
    "LightGBM": LGBMClassifier(objective='multiclass', num_class=len(np.unique(y_awid2trn)), metric='multi_logloss',
                               boosting_type='gbdt', num_leaves=20, learning_rate=0.01, max_bin=20, max_depth=10,
                               min_child_samples=30, min_data_in_bin=10, min_split_gain=0.1, n_estimators=80,
                               reg_alpha=0.01, reg_lambda=0.01, n_jobs=1, verbose=0),
    "Logistic Regression": LogisticRegression(solver='sag', max_iter=1000, tol=0.01, random_state=42, multi_class='multinomial'),
    "SGDClassifier": SGDClassifier(tol=1e-05, loss='modified_huber', early_stopping=True, random_state=42),
    "LinearSVC": LinearSVC(max_iter=20000, C=1.5, random_state=42),
    "Random Forest": RandomForestClassifier(max_depth=20, ccp_alpha=0.001, max_leaf_nodes=100, min_samples_leaf=2, random_state=42),
    "Extra Trees": ExtraTreesClassifier(max_depth=200, n_estimators=200, ccp_alpha=0.0001, max_leaf_nodes=500,
                                       min_samples_leaf=2, min_samples_split=10, random_state=42, n_jobs=-1)
}

# Her model için sınıf bazlı metrik hesaplama
for model_name, model in models.items():
    print(f"\n📌 {model_name} için K-Fold değerlendirmesi başlatılıyor...")
    results_list = []

    # Etiketleri kategorik koda çevir (SMOTE sonrası)
    y_awid2trn_encoded = y_awid2trn.astype('category').cat.codes
    class_names = y_awid2trn.astype('category').cat.categories

    for fold, (train_index, test_index) in enumerate(stratified_kfold.split(X_awid2trn_encoded, y_awid2trn_encoded)):
        print(f"Fold {fold + 1} başlatılıyor...")

        # Veriyi ayır
        X_train, X_test = X_awid2trn_encoded.iloc[train_index], X_awid2trn_encoded.iloc[test_index]
        y_train_enc, y_test_enc = y_awid2trn_encoded.iloc[train_index], y_awid2trn_encoded.iloc[test_index]

        # Modeli eğit
        model.fit(X_train, y_train_enc)
        y_pred = model.predict(X_test)

        # Sınıf bazlı metrikleri hesapla
        report = classification_report(y_test_enc, y_pred, target_names=class_names, output_dict=True, zero_division=0)
        df_report = pd.DataFrame(report).transpose()
        df_classes = df_report.iloc[:-3][['precision', 'recall', 'f1-score']]
        df_classes['fold'] = fold + 1

        results_list.append(df_classes)

        # Karışıklık matrisini hesapla ve görselleştir
        cm = confusion_matrix(y_test_enc, y_pred)
        plt.figure(figsize=(10, 10))
        sns.heatmap(cm, annot=True, fmt='.2f', cmap='Blues', cbar=False, xticklabels=class_names, yticklabels=class_names)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title(f'Confusion Matrix for Fold {fold + 1} ({model_name})')
        plt.show()

    # Tüm fold'ları birleştir
    df_all = pd.concat(results_list)

    # Ortalama metrikleri hesapla
    df_avg = df_all.groupby(df_all.index)[['precision', 'recall', 'f1-score']].mean()

    # Sonucu yazdır
    print(f"📌 {model_name} - Sınıf Bazlı Ortalama Metrikler (10 Fold):")
    display(df_avg)

    # Test seti üzerinde değerlendirme
    model.fit(X_awid2trn_encoded, y_awid2trn_encoded)
    y_test_enc = y_awid2tst.astype('category').cat.codes
    y_test_pred = model.predict(X_awid2tst_encoded)

    # Test seti için sınıf bazlı metrikler
    report_test = classification_report(y_test_enc, y_test_pred, target_names=class_names, output_dict=True, zero_division=0)
    df_report_test = pd.DataFrame(report_test).transpose()
    df_test_classes = df_report_test.iloc[:-3][['precision', 'recall', 'f1-score']]

    print(f"\n📌 {model_name} - Test Seti Sınıf Bazlı Metrikler:")
    display(df_test_classes)

    # Test seti için karışıklık matrisi
    cm_test = confusion_matrix(y_test_enc, y_test_pred)
    plt.figure(figsize=(10, 10))
    sns.heatmap(cm_test, annot=True, fmt='.2f', cmap='Blues', cbar=False, xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix for Test Set ({model_name})')
    plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 5.4 MB/s eta 0:00:00
# ...
# SMOTE öncesi sınıf dağılımı:
# class
# normal           1631218
# impersonation      48522
# flooding           48484
# Name: count, dtype: int64
# SMOTE sonrası sınıf dağılımı:
# class
# normal           1631218
# flooding         1631218
# impersonation    1631218
# Name: count, dtype: int64
#
# 📌 Decision Tree için K-Fold değerlendirmesi başlatılıyor...
# Fold 1 başlatılıyor...
# Fold 2 başlatılıyor...
# Fold 3 başlatılıyor...
# Fold 4 başlatılıyor...
# Fold 5 başlatılıyor...
# Fold 6 başlatılıyor...
# Fold 7 başlatılıyor...
# Fold 8 başlatılıyor...
# Fold 9 başlatılıyor...
# Fold 10 başlatılıyor...
# 📌 Decision Tree - Sınıf Bazlı Ortalama Metrikler (10 Fold):
#                precision    recall  f1-score
# ...

# %% [markdown]
# # DNN

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
import warnings

# Uyarıları kapat
warnings.filterwarnings('ignore')

# dBm_antsignal için özel dönüştürme fonksiyonu
def convert_to_integer(value):
    if pd.isna(value) or value == '':
        return None
    elif isinstance(value, int) or isinstance(value, float):
        return value
    else:
        signal_strengths = [int(v) for v in value.split('-') if v]
        if signal_strengths:
            average_strength = round(sum(signal_strengths) / len(signal_strengths))
            return -average_strength
        else:
            return None

# Hexadecimal'den float'a dönüştürme
def convert_hex_to_float(value):
    if isinstance(value, str):
        return float(int(value, 16))
    else:
        return value

# AWID2 öznitelikleri
features = ['frame.interface_id', 'frame.dlt', 'frame.offset_shift', 'frame.time_epoch', 'frame.time_delta',
            'frame.time_delta_displayed', 'frame.time_relative', 'frame.len', 'frame.cap_len', 'frame.marked',
            'frame.ignored', 'radiotap.version', 'radiotap.pad', 'radiotap.length', 'radiotap.present.tsft',
            'radiotap.present.flags', 'radiotap.present.rate', 'radiotap.present.channel', 'radiotap.present.fhss',
            'radiotap.present.dbm_antsignal', 'radiotap.present.dbm_antnoise', 'radiotap.present.lock_quality',
            'radiotap.present.tx_attenuation', 'radiotap.present.db_tx_attenuation', 'radiotap.present.dbm_tx_power',
            'radiotap.present.antenna', 'radiotap.present.db_antsignal', 'radiotap.present.db_antnoise',
            'radiotap.present.rxflags', 'radiotap.present.xchannel', 'radiotap.present.mcs', 'radiotap.present.ampdu',
            'radiotap.present.vht', 'radiotap.present.reserved', 'radiotap.present.rtap_ns', 'radiotap.present.vendor_ns',
            'radiotap.present.ext', 'radiotap.mactime', 'radiotap.flags.cfp', 'radiotap.flags.preamble',
            'radiotap.flags.wep', 'radiotap.flags.frag', 'radiotap.flags.fcs', 'radiotap.flags.datapad',
            'radiotap.flags.badfcs', 'radiotap.flags.shortgi', 'radiotap.datarate', 'radiotap.channel.freq',
            'radiotap.channel.type.turbo', 'radiotap.channel.type.cck', 'radiotap.channel.type.ofdm',
            'radiotap.channel.type.2ghz', 'radiotap.channel.type.5ghz', 'radiotap.channel.type.passive',
            'radiotap.channel.type.dynamic', 'radiotap.channel.type.gfsk', 'radiotap.channel.type.gsm',
            'radiotap.channel.type.sturbo', 'radiotap.channel.type.half', 'radiotap.channel.type.quarter',
            'radiotap.dbm_antsignal', 'radiotap.antenna', 'radiotap.rxflags.badplcp', 'wlan.fc.type_subtype',
            'wlan.fc.version', 'wlan.fc.type', 'wlan.fc.subtype', 'wlan.fc.ds', 'wlan.fc.frag', 'wlan.fc.retry',
            'wlan.fc.pwrmgt', 'wlan.fc.moredata', 'wlan.fc.protected', 'wlan.fc.order', 'wlan.duration', 'wlan.ra',
            'wlan.da', 'wlan.ta', 'wlan.sa', 'wlan.bssid', 'wlan.frag', 'wlan.seq', 'wlan.bar.type',
            'wlan.ba.control.ackpolicy', 'wlan.ba.control.multitid', 'wlan.ba.control.cbitmap',
            'wlan.bar.compressed.tidinfo', 'wlan.ba.bm', 'wlan.fcs_good', 'wlan_mgt.fixed.capabilities.ess',
            'wlan_mgt.fixed.capabilities.ibss', 'wlan_mgt.fixed.capabilities.cfpoll.ap',
            'wlan_mgt.fixed.capabilities.privacy', 'wlan_mgt.fixed.capabilities.preamble',
            'wlan_mgt.fixed.capabilities.pbcc', 'wlan_mgt.fixed.capabilities.agility',
            'wlan_mgt.fixed.capabilities.spec_man', 'wlan_mgt.fixed.capabilities.short_slot_time',
            'wlan_mgt.fixed.capabilities.apsd', 'wlan_mgt.fixed.capabilities.radio_measurement',
            'wlan_mgt.fixed.capabilities.dsss_ofdm', 'wlan_mgt.fixed.capabilities.del_blk_ack',
            'wlan_mgt.fixed.capabilities.imm_blk_ack', 'wlan_mgt.fixed.listen_ival', 'wlan_mgt.fixed.current_ap',
            'wlan_mgt.fixed.status_code', 'wlan_mgt.fixed.timestamp', 'wlan_mgt.fixed.beacon', 'wlan_mgt.fixed.aid',
            'wlan_mgt.fixed.reason_code', 'wlan_mgt.fixed.auth.alg', 'wlan_mgt.fixed.auth_seq',
            'wlan_mgt.fixed.category_code', 'wlan_mgt.fixed.htact', 'wlan_mgt.fixed.chanwidth',
            'wlan_mgt.fixed.fragment', 'wlan_mgt.fixed.sequence', 'wlan_mgt.tagged.all', 'wlan_mgt.ssid',
            'wlan_mgt.ds.current_channel', 'wlan_mgt.tim.dtim_count', 'wlan_mgt.tim.dtim_period',
            'wlan_mgt.tim.bmapctl.multicast', 'wlan_mgt.tim.bmapctl.offset', 'wlan_mgt.country_info.environment',
            'wlan_mgt.rsn.version', 'wlan_mgt.rsn.gcs.type', 'wlan_mgt.rsn.pcs.count', 'wlan_mgt.rsn.akms.count',
            'wlan_mgt.rsn.akms.type', 'wlan_mgt.rsn.capabilities.preauth', 'wlan_mgt.rsn.capabilities.no_pairwise',
            'wlan_mgt.rsn.capabilities.ptksa_replay_counter', 'wlan_mgt.rsn.capabilities.gtksa_replay_counter',
            'wlan_mgt.rsn.capabilities.mfpr', 'wlan_mgt.rsn.capabilities.mfpc', 'wlan_mgt.rsn.capabilities.peerkey',
            'wlan_mgt.tcprep.trsmt_pow', 'wlan_mgt.tcprep.link_mrg', 'wlan.wep.iv', 'wlan.wep.key', 'wlan.wep.icv',
            'wlan.tkip.extiv', 'wlan.ccmp.extiv', 'wlan.qos.tid', 'wlan.qos.priority', 'wlan.qos.eosp',
            'wlan.qos.ack', 'wlan.qos.amsdupresent', 'wlan.qos.buf_state_indicated1', 'wlan.qos.bit4',
            'wlan.qos.txop_dur_req', 'wlan.qos.buf_state_indicated2', 'data.len', 'class']

# Seçilen öznitelikler
selected_features = ['frame.len', 'radiotap.length', 'radiotap.dbm_antsignal', 'radiotap.channel.freq',
                    'wlan.duration', 'radiotap.present.tsft', 'radiotap.channel.type.cck',
                    'radiotap.channel.type.ofdm', 'wlan.fc.type', 'wlan.fc.subtype', 'wlan.fc.ds',
                    'wlan.fc.frag', 'wlan.fc.retry', 'wlan.fc.pwrmgt', 'wlan.fc.moredata', 'wlan.fc.protected']

# AWID2 sınıfları
awid2_classes = ['Flooding', 'Impersonation', 'Injection', 'Normal']

# Veri setini oku
awid2trn_data = pd.read_csv("/content/drive/MyDrive/AWID/AWID2/DATASET/AWID-CLS-R-Trn/AWID-CLS-R-Trn/1",
                            header=None, names=features, low_memory=False)

# Seçilen öznitelikleri ve sınıf etiketini al
awid2trn_data = awid2trn_data.loc[:, selected_features + ['class']]

# Veri ön işleme
# 1. Eksik verileri ('?') NaN ile değiştir
awid2trn_data.replace('?', pd.NA, inplace=True)

# 2. radiotap.dbm_antsignal için özel dönüştürme
awid2trn_data['radiotap.dbm_antsignal'] = awid2trn_data['radiotap.dbm_antsignal'].apply(convert_to_integer)

# 3. Hexadecimal öznitelikler için dönüşüm
hex_columns = ['wlan.fc.ds']  # wlan.fc.ds genellikle hex formatında
for col in hex_columns:
    awid2trn_data[col] = awid2trn_data[col].apply(convert_hex_to_float)

# 4. Eksik verileri çıkar
awid2trn_data.dropna(inplace=True)

# 5. Sayısal olmayan sütunları kontrol et ve dönüştür
for col in selected_features:
    if awid2trn_data[col].dtype == 'object':
        awid2trn_data[col] = pd.to_numeric(awid2trn_data[col], errors='coerce')
awid2trn_data.dropna(inplace=True)

# 6. Normalizasyon (StandardScaler)
scaler = StandardScaler()
X = scaler.fit_transform(awid2trn_data[selected_features])
y = awid2trn_data[['class']]

# Train/test böl
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# SMOTE uygula
smote = SMOTE(sampling_strategy="not majority", random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# Float32 dönüşümü
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# 10-katlı çapraz doğrulama
k_folds = 10
stratified_kfold = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# DNN Modeli
def train_and_eval_dnn(X_train, y_train, X_test, y_test):
    label_encoder = LabelEncoder()
    y_train_enc = label_encoder.fit_transform(y_train['class'])
    y_test_enc = label_encoder.transform(y_test['class'])
    y_train_cat = to_categorical(y_train_enc)
    y_test_cat = to_categorical(y_test_enc)

    input_dim = X_train.shape[1]
    num_classes = len(awid2_classes)

    # AWID2 için hafif DNN
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_dim,)),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        Dropout(0.1),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )

    # Eğitim
    model.fit(
        X_train,
        y_train_cat,
        validation_data=(X_test, y_test_cat),
        epochs=10,
        batch_size=128,
        verbose=1
    )

    # Tahmin
    y_pred_proba = model.predict(X_test)
    y_pred = y_pred_proba.argmax(axis=1)

    # Metrikler
    report = classification_report(y_test_enc, y_pred, target_names=awid2_classes, output_dict=True)
    df_report = pd.DataFrame(report).transpose()
    accuracy = accuracy_score(y_test_enc, y_pred)

    return df_report, accuracy, y_test_enc, y_pred

# Çapraz doğrulama sonuçları
dnn_results = []

for fold, (train_index, test_index) in enumerate(stratified_kfold.split(X, y)):
    print(f"Fold {fold+1} başlatılıyor...")
    X_train_fold, X_test_fold = X[train_index], X[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]

    # DNN
    dnn_report, dnn_accuracy, y_test_enc, y_pred = train_and_eval_dnn(X_train_fold, y_train_fold, X_test_fold, y_test_fold)
    dnn_results.append((dnn_report, dnn_accuracy, y_test_enc, y_pred))

# Ortalama metrikleri yazdır
def print_average_results(name, results_list):
    df_all = pd.concat([result[0] for result in results_list])
    df_avg = df_all.groupby(df_all.index)[['precision', 'recall', 'f1-score']].mean()
    accuracy_avg = sum(result[1] for result in results_list) / len(results_list)

    print(f"\n📌 {name} - Sınıf Bazlı Ortalama Metrikler (10 Fold):")
    display(df_avg.iloc[:-3])  # Son 3 satır (accuracy, macro, weighted) hariç
    print(f"\n✅ Ortalama Accuracy: {round(accuracy_avg, 4)}")

    # Confusion Matrix (son fold için)
    cm = confusion_matrix(results_list[-1][2], results_list[-1][3], labels=range(len(awid2_classes)))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='.0f', cmap='Blues', xticklabels=awid2_classes, yticklabels=awid2_classes)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix for {name} (Last Fold)')
    plt.show()

# Sonuçları göster
print_average_results("Deep Neural Network", dnn_results)
# Out:
# Fold 1 başlatılıyor...
# Epoch 1/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.9795 - loss: 0.0580 - val_accuracy: 0.9944 - val_loss: 0.0183
# Epoch 2/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.9931 - loss: 0.0218 - val_accuracy: 0.9948 - val_loss: 0.0163
# Epoch 3/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.9937 - loss: 0.0196 - val_accuracy: 0.9942 - val_loss: 0.0170
# Epoch 4/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9938 - loss: 0.0189 - val_accuracy: 0.9948 - val_loss: 0.0162
# Epoch 5/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9939 - loss: 0.0184 - val_accuracy: 0.9945 - val_loss: 0.0165
# Epoch 6/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - accuracy: 0.9942 - loss: 0.0179 - val_accuracy: 0.9950 - val_loss: 0.0150
# Epoch 7/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.9941 - loss: 0.0178 - val_accuracy: 0.9950 - val_loss: 0.0154
# Epoch 8/10
# ...

# %% [markdown]
# # CNN

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
import warnings

# Uyarıları kapat
warnings.filterwarnings('ignore')

# dBm_antsignal için özel dönüştürme fonksiyonu
def convert_to_integer(value):
    if pd.isna(value) or value == '':
        return None
    elif isinstance(value, int) or isinstance(value, float):
        return value
    else:
        signal_strengths = [int(v) for v in value.split('-') if v]
        if signal_strengths:
            average_strength = round(sum(signal_strengths) / len(signal_strengths))
            return -average_strength
        else:
            return None

# Hexadecimal'den float'a dönüştürme
def convert_hex_to_float(value):
    if isinstance(value, str):
        return float(int(value, 16))
    else:
        return value

# AWID2 öznitelikleri
features = ['frame.interface_id', 'frame.dlt', 'frame.offset_shift', 'frame.time_epoch', 'frame.time_delta',
            'frame.time_delta_displayed', 'frame.time_relative', 'frame.len', 'frame.cap_len', 'frame.marked',
            'frame.ignored', 'radiotap.version', 'radiotap.pad', 'radiotap.length', 'radiotap.present.tsft',
            'radiotap.present.flags', 'radiotap.present.rate', 'radiotap.present.channel', 'radiotap.present.fhss',
            'radiotap.present.dbm_antsignal', 'radiotap.present.dbm_antnoise', 'radiotap.present.lock_quality',
            'radiotap.present.tx_attenuation', 'radiotap.present.db_tx_attenuation', 'radiotap.present.dbm_tx_power',
            'radiotap.present.antenna', 'radiotap.present.db_antsignal', 'radiotap.present.db_antnoise',
            'radiotap.present.rxflags', 'radiotap.present.xchannel', 'radiotap.present.mcs', 'radiotap.present.ampdu',
            'radiotap.present.vht', 'radiotap.present.reserved', 'radiotap.present.rtap_ns', 'radiotap.present.vendor_ns',
            'radiotap.present.ext', 'radiotap.mactime', 'radiotap.flags.cfp', 'radiotap.flags.preamble',
            'radiotap.flags.wep', 'radiotap.flags.frag', 'radiotap.flags.fcs', 'radiotap.flags.datapad',
            'radiotap.flags.badfcs', 'radiotap.flags.shortgi', 'radiotap.datarate', 'radiotap.channel.freq',
            'radiotap.channel.type.turbo', 'radiotap.channel.type.cck', 'radiotap.channel.type.ofdm',
            'radiotap.channel.type.2ghz', 'radiotap.channel.type.5ghz', 'radiotap.channel.type.passive',
            'radiotap.channel.type.dynamic', 'radiotap.channel.type.gfsk', 'radiotap.channel.type.gsm',
            'radiotap.channel.type.sturbo', 'radiotap.channel.type.half', 'radiotap.channel.type.quarter',
            'radiotap.dbm_antsignal', 'radiotap.antenna', 'radiotap.rxflags.badplcp', 'wlan.fc.type_subtype',
            'wlan.fc.version', 'wlan.fc.type', 'wlan.fc.subtype', 'wlan.fc.ds', 'wlan.fc.frag', 'wlan.fc.retry',
            'wlan.fc.pwrmgt', 'wlan.fc.moredata', 'wlan.fc.protected', 'wlan.fc.order', 'wlan.duration', 'wlan.ra',
            'wlan.da', 'wlan.ta', 'wlan.sa', 'wlan.bssid', 'wlan.frag', 'wlan.seq', 'wlan.bar.type',
            'wlan.ba.control.ackpolicy', 'wlan.ba.control.multitid', 'wlan.ba.control.cbitmap',
            'wlan.bar.compressed.tidinfo', 'wlan.ba.bm', 'wlan.fcs_good', 'wlan_mgt.fixed.capabilities.ess',
            'wlan_mgt.fixed.capabilities.ibss', 'wlan_mgt.fixed.capabilities.cfpoll.ap',
            'wlan_mgt.fixed.capabilities.privacy', 'wlan_mgt.fixed.capabilities.preamble',
            'wlan_mgt.fixed.capabilities.pbcc', 'wlan_mgt.fixed.capabilities.agility',
            'wlan_mgt.fixed.capabilities.spec_man', 'wlan_mgt.fixed.capabilities.short_slot_time',
            'wlan_mgt.fixed.capabilities.apsd', 'wlan_mgt.fixed.capabilities.radio_measurement',
            'wlan_mgt.fixed.capabilities.dsss_ofdm', 'wlan_mgt.fixed.capabilities.del_blk_ack',
            'wlan_mgt.fixed.capabilities.imm_blk_ack', 'wlan_mgt.fixed.listen_ival', 'wlan_mgt.fixed.current_ap',
            'wlan_mgt.fixed.status_code', 'wlan_mgt.fixed.timestamp', 'wlan_mgt.fixed.beacon', 'wlan_mgt.fixed.aid',
            'wlan_mgt.fixed.reason_code', 'wlan_mgt.fixed.auth.alg', 'wlan_mgt.fixed.auth_seq',
            'wlan_mgt.fixed.category_code', 'wlan_mgt.fixed.htact', 'wlan_mgt.fixed.chanwidth',
            'wlan_mgt.fixed.fragment', 'wlan_mgt.fixed.sequence', 'wlan_mgt.tagged.all', 'wlan_mgt.ssid',
            'wlan_mgt.ds.current_channel', 'wlan_mgt.tim.dtim_count', 'wlan_mgt.tim.dtim_period',
            'wlan_mgt.tim.bmapctl.multicast', 'wlan_mgt.tim.bmapctl.offset', 'wlan_mgt.country_info.environment',
            'wlan_mgt.rsn.version', 'wlan_mgt.rsn.gcs.type', 'wlan_mgt.rsn.pcs.count', 'wlan_mgt.rsn.akms.count',
            'wlan_mgt.rsn.akms.type', 'wlan_mgt.rsn.capabilities.preauth', 'wlan_mgt.rsn.capabilities.no_pairwise',
            'wlan_mgt.rsn.capabilities.ptksa_replay_counter', 'wlan_mgt.rsn.capabilities.gtksa_replay_counter',
            'wlan_mgt.rsn.capabilities.mfpr', 'wlan_mgt.rsn.capabilities.mfpc', 'wlan_mgt.rsn.capabilities.peerkey',
            'wlan_mgt.tcprep.trsmt_pow', 'wlan_mgt.tcprep.link_mrg', 'wlan.wep.iv', 'wlan.wep.key', 'wlan.wep.icv',
            'wlan.tkip.extiv', 'wlan.ccmp.extiv', 'wlan.qos.tid', 'wlan.qos.priority', 'wlan.qos.eosp',
            'wlan.qos.ack', 'wlan.qos.amsdupresent', 'wlan.qos.buf_state_indicated1', 'wlan.qos.bit4',
            'wlan.qos.txop_dur_req', 'wlan.qos.buf_state_indicated2', 'data.len', 'class']

# Seçilen öznitelikler
selected_features = ['frame.len', 'radiotap.length', 'radiotap.dbm_antsignal', 'radiotap.channel.freq',
                    'wlan.duration', 'radiotap.present.tsft', 'radiotap.channel.type.cck',
                    'radiotap.channel.type.ofdm', 'wlan.fc.type', 'wlan.fc.subtype', 'wlan.fc.ds',
                    'wlan.fc.frag', 'wlan.fc.retry', 'wlan.fc.pwrmgt', 'wlan.fc.moredata', 'wlan.fc.protected']

# AWID2 sınıfları
awid2_classes = ['Flooding', 'Impersonation', 'Injection', 'Normal']

# Veri setini oku
awid2trn_data = pd.read_csv("/content/drive/MyDrive/AWID/AWID2/DATASET/AWID-CLS-R-Trn/AWID-CLS-R-Trn/1",
                            header=None, names=features, low_memory=False)

# Seçilen öznitelikleri ve sınıf etiketini al
awid2trn_data = awid2trn_data.loc[:, selected_features + ['class']]

# Veri ön işleme
# 1. Eksik verileri ('?') NaN ile değiştir
awid2trn_data.replace('?', pd.NA, inplace=True)

# 2. radiotap.dbm_antsignal için özel dönüştürme
awid2trn_data['radiotap.dbm_antsignal'] = awid2trn_data['radiotap.dbm_antsignal'].apply(convert_to_integer)

# 3. Hexadecimal öznitelikler için dönüşüm
hex_columns = ['wlan.fc.ds']  # wlan.fc.ds genellikle hex formatında
for col in hex_columns:
    awid2trn_data[col] = awid2trn_data[col].apply(convert_hex_to_float)

# 4. Eksik verileri çıkar
awid2trn_data.dropna(inplace=True)

# 5. Sayısal olmayan sütunları kontrol et ve dönüştür
for col in selected_features:
    if awid2trn_data[col].dtype == 'object':
        awid2trn_data[col] = pd.to_numeric(awid2trn_data[col], errors='coerce')
awid2trn_data.dropna(inplace=True)

# 6. Normalizasyon (StandardScaler)
scaler = StandardScaler()
X = scaler.fit_transform(awid2trn_data[selected_features])
y = awid2trn_data[['class']]

# Train/test böl
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# SMOTE uygula
smote = SMOTE(sampling_strategy="not majority", random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# Float32 dönüşümü
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# 10-katlı çapraz doğrulama
k_folds = 10
stratified_kfold = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# CNN Modeli
def train_and_eval_cnn(X_train, y_train, X_test, y_test):
    label_encoder = LabelEncoder()
    y_train_enc = label_encoder.fit_transform(y_train['class'])
    y_test_enc = label_encoder.transform(y_test['class'])
    y_train_cat = to_categorical(y_train_enc)
    y_test_cat = to_categorical(y_test_enc)
    class_names = awid2_classes

    # CNN için giriş şekli: (num_samples, num_features, 1)
    X_train_cnn = X_train.reshape((X_train.shape[0], X_train.shape[1], 1)).astype(np.float32)
    X_test_cnn = X_test.reshape((X_test.shape[0], X_test.shape[1], 1)).astype(np.float32)

    # AWID2 için sadeleştirilmiş CNN modeli
    model = Sequential([
        Conv1D(filters=16, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),
        Conv1D(filters=32, kernel_size=3, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(len(class_names), activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Eğitim
    model.fit(
        X_train_cnn,
        y_train_cat,
        validation_data=(X_test_cnn, y_test_cat),
        epochs=10,
        batch_size=128,
        verbose=1
    )

    # Tahmin
    y_pred_proba = model.predict(X_test_cnn)
    y_pred = y_pred_proba.argmax(axis=1)

    # Metrikler
    report = classification_report(y_test_enc, y_pred, target_names=class_names, output_dict=True)
    df_report = pd.DataFrame(report).transpose()
    accuracy = accuracy_score(y_test_enc, y_pred)

    return df_report, accuracy, y_test_enc, y_pred

# Çapraz doğrulama sonuçları
cnn_results = []

for fold, (train_index, test_index) in enumerate(stratified_kfold.split(X, y)):
    print(f"Fold {fold+1} başlatılıyor...")
    X_train_fold, X_test_fold = X[train_index], X[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]

    # CNN
    cnn_report, cnn_accuracy, y_test_enc, y_pred = train_and_eval_cnn(X_train_fold, y_train_fold, X_test_fold, y_test_fold)
    cnn_results.append((cnn_report, cnn_accuracy, y_test_enc, y_pred))

# Ortalama metrikleri yazdır
def print_average_results(name, results_list):
    df_all = pd.concat([result[0] for result in results_list])
    df_avg = df_all.groupby(df_all.index)[['precision', 'recall', 'f1-score']].mean()
    accuracy_avg = sum(result[1] for result in results_list) / len(results_list)

    print(f"\n📌 {name} - Sınıf Bazlı Ortalama Metrikler (10 Fold):")
    display(df_avg.iloc[:-3])  # Son 3 satır (accuracy, macro, weighted) hariç
    print(f"\n✅ Ortalama Accuracy: {round(accuracy_avg, 4)}")

    # Confusion Matrix (son fold için)
    cm = confusion_matrix(results_list[-1][2], results_list[-1][3], labels=range(len(awid2_classes)))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='.0f', cmap='Blues', xticklabels=awid2_classes, yticklabels=awid2_classes)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix for {name} (Last Fold)')
    plt.show()

# Sonuçları göster
print_average_results("Convolutional Neural Network", cnn_results)
# Out:
# Fold 1 başlatılıyor...
# Epoch 1/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 57s 4ms/step - accuracy: 0.9720 - loss: 0.0809 - val_accuracy: 0.9922 - val_loss: 0.0262
# Epoch 2/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - accuracy: 0.9890 - loss: 0.0348 - val_accuracy: 0.9926 - val_loss: 0.0244
# Epoch 3/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - accuracy: 0.9899 - loss: 0.0326 - val_accuracy: 0.9934 - val_loss: 0.0239
# Epoch 4/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 55s 4ms/step - accuracy: 0.9904 - loss: 0.0310 - val_accuracy: 0.9936 - val_loss: 0.0220
# Epoch 5/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - accuracy: 0.9908 - loss: 0.0297 - val_accuracy: 0.9936 - val_loss: 0.0211
# Epoch 6/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 55s 4ms/step - accuracy: 0.9911 - loss: 0.0281 - val_accuracy: 0.9935 - val_loss: 0.0193
# Epoch 7/10
# 12612/12612 ━━━━━━━━━━━━━━━━━━━━ 55s 4ms/step - accuracy: 0.9913 - loss: 0.0277 - val_accuracy: 0.9939 - val_loss: 0.0187
# Epoch 8/10
# ...
